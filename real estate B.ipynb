# %%
# !pip install bs4
# !pip install requests

# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
url='https://housing.com/in/buy/searches/M74P4ie9y33s0tezykdb'

# %%
page=requests.get(url)
page.content
# Out:
# b'<!doctype html><html lang="en" prefix="og: http://ogp.me/ns# website: http://ogp.me/ns/website#"><head><link rel="preconnect" href="//c.housingcdn.com"/><link rel="preconnect" href="//is1-3.housingcdn.com"/><link rel="preconnect" href="//eventrouter.housing.com"/><link rel="preconnect" href="//img.youtube.com"/><link rel="preconnect" href="//is1-2.housingcdn.com"/><meta http-equiv="origin-trial" content="AsgGWjPX2xx12aBpNxa8enFVy/0d/Ghc/GLjQO1gdmgn6eayydZJK0TGTifjIngm+7B4rWjfgVoyHZFbeKq0pg4AAABgeyJvcmlnaW4iOiJodHRwczovL2hvdXNpbmcuY29tOjQ0MyIsImZlYXR1cmUiOiJXYWtlTG9jayIsImV4cGlyeSI6MTU5MTA5NTk2MSwiaXNTdWJkb21haW4iOnRydWV9"/><meta name="referrer" content="no-referrer-when-downgrade"/><link rel="prefetch" href="//c.housingcdn.com/demand/s/client/common/assets/loader.fd27d2ce.svg" as="image"/><title itemProp="name">Villas for Sale in Whitefield, Bangalore | 136+ Independent Villas in Whitefield, Bangalore</title><script type="application/ld+json">[{"@context":"http://schema.org","@type
# ...

# %%
price= soup.find('div', class_="_csbfng _c8f6fq _g3gktf _ldyh40 _7l1ulh T_a6707275")
price
# Out:
# <div class="_csbfng _c8f6fq _g3gktf _ldyh40 _7l1ulh T_a6707275" data-testid="priceid">₹2.94 Cr - 6.06 Cr</div>

# %%
price.text
# Out:
# '₹2.94 Cr - 6.06 Cr'

# %%
price= []

for i in soup.find_all('div', class_="_csbfng _c8f6fq _g3gktf _ldyh40 _7l1ulh T_a6707275"):
     price.append(i.text)
price
# Out:
# ['₹2.94 Cr - 6.06 Cr',
#  '₹3.24 Cr',
#  '₹2.81 Cr - 7.74 Cr',
#  '₹2.93 Cr - 7.18 Cr',
#  '₹2.77 Cr',
#  '₹2.33 Cr',
#  '₹2.85 Cr',
#  '₹2.12 Cr',
#  '₹4.06 Cr',
#  '₹1.49 Cr',
#  '₹4.49 Cr',
#  '₹4.4 Cr',
#  '₹6.53 Cr',
#  '₹6.91 Cr',
#  '₹4.42 Cr',
#  '₹8.57 Cr',
#  '₹6.0 Cr',
#  '₹9.0 Cr',
#  '₹4.51 Cr',
#  '₹11.0 Cr',
#  '₹2.75 Cr',
#  '₹2.7 Cr',
#  '₹2.9 Cr',
#  '₹2.8 Cr',
#  '₹4.43 Cr',
#  '₹4.93 Cr',
#  '₹4.44 Cr',
#  '₹4.06 Cr',
#  '₹4.93 Cr',
#  '₹4.93 Cr']

# %%
address= soup.find('h2', class_="T_4d93cd45 _7s5wglyw _1u71grho _gi182v")
address
# Out:
# <h2 class="T_4d93cd45 _7s5wglyw _1u71grho _gi182v">Prestige Park Grove</h2>

# %%
address.text
# Out:
# 'Prestige Park Grove'

# %%
address= []

for i in soup.find_all('div', class_="T_091c165f _sq1l2s _vv1q9c _ks15vq T_3d3547ab _7s5wglyw _5vy24jg8 _blas1v10 new-title"):
     address.append(i.text)
address
# Out:
# ['4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '3 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '3 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '3 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '5 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
#  '4 BHK Villa for sale in Whitefield',
# ...

# %%
data = ['4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '3 BHK Villa for sale in Whitefield',
 '3 BHK Villa for sale in Whitefield',
 '3 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '3 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '5 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '5 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '3 BHK Villa for sale in Whitefield',
 '3 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield',
 '4 BHK Villa for sale in Whitefield']

bhk_list = []
address_list = []

for item in data:
    parts = item.split(' ')
    bhk = parts[0] 
    address = ' '.join(parts[5:])  
    bhk_list.append(bhk)
    address_list.append(address)

print("BHK List:", bhk_list)
print("Address List:", address_list)
# Out:
# BHK List: ['4', '4', '4', '4', '3', '3', '3', '4', '4', '3', '4', '4', '4', '5', '4', '4', '4', '5', '4', '4', '3', '3', '4', '4']
# Address List: ['in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield', 'in Whitefield']

# %%
address= []

for i in soup.find_all('div', class_="_9s1txw _ar1bp4 _amkb7n _fc1h6o _r31e5h _gzftgi T_f121fc5f"):
     address.append(i.text)
address
# Out:
# ['Possession DateJun, 2028',
#  'Average Price₹14.53 K/sq.ft',
#  'Possession StatusUnder Construction',
#  'Possession DateJun, 2028',
#  'Average Price₹14.53 K/sq.ft',
#  'Possession StatusUnder Construction',
#  'Sizes2021.00 sq.ft. - 4170.00 sq.ft.',
#  'LocalityWhitefield,Bangalore East ,Bangalore',
#  'Possession DateJun, 2021',
#  'Average Price₹6.26k/sq.ft',
#  'Possession StatusReady to Move',
#  'Possession DateJun, 2021',
#  'Average Price₹6.26k/sq.ft',
#  'Possession StatusReady to Move',
#  'Sizes3565.00 sq.ft.',
#  'LocalityWhitefield, Bengaluru',
#  'Possession DateAug, 2014',
#  'Average Price₹15.20 K/sq.ft',
#  'Possession StatusReady to Move',
#  'Possession DateAug, 2014',
#  'Average Price₹15.20 K/sq.ft',
#  'Possession StatusReady to Move',
#  'Sizes1851.00 sq.ft. - 5091.00 sq.ft.',
#  'LocalityWhitefield,Bangalore East ,Bangalore',
#  'Possession DateJul, 2024',
#  'Average Price₹10.64 K - 12.63 K/sq.ft',
#  'Possession StatusUnder Construction',
# ...

# %%
data = ['Possession DateJun, 2028',
 'Average Price₹14.53 K/sq.ft',
 'Possession StatusUnder Construction',
 'Possession DateJun, 2028',
 'Average Price₹14.53 K/sq.ft',
 'Possession StatusUnder Construction',
 'Sizes2021.00 sq.ft. - 4170.00 sq.ft.',
 'LocalityWhitefield,Bangalore East ,Bangalore',
 'Possession DateAug, 2023',
 'Average Price₹8.4k/sq.ft',
 'Possession StatusReady to Move',
 'Possession DateAug, 2023',
 'Average Price₹8.4k/sq.ft',
 'Possession StatusReady to Move',
 'Sizes3300.00 sq.ft.',
 'LocalityThimmadahalli,Bangalore East ,Bangalore',
 'Possession DateJul, 2024',
 'Average Price₹10.64 K - 12.63 K/sq.ft',
 'Possession StatusUnder Construction',
 'Possession DateJul, 2024',
 'Average Price₹10.64 K - 12.63 K/sq.ft',
 'Possession StatusUnder Construction',
 'Sizes2753.00 sq.ft. - 5683.00 sq.ft.',
 'LocalityKrishnarajapura,Bangalore East ,Bangalore',
 'Possession DateDec, 2024',
 'Average Price₹12.00 K/sq.ft',
 'Possession StatusUnder Construction',
 'Possession DateDec, 2024',
 'Average Price₹12.00 K/sq.ft',
 'Possession StatusUnder Construction',
 'Sizes2688.00 sq.ft. - 5430.00 sq.ft.',
 'LocalityWhitefield,Bangalore East ,Bangalore',
 'Possession DateJun, 2021',
 'Average Price₹6.26k/sq.ft',
 'Possession StatusReady to Move',
 'Possession DateJun, 2021',
 'Average Price₹6.26k/sq.ft',
 'Possession StatusReady to Move',
 'Sizes3565.00 sq.ft.',
 'LocalityWhitefield, Bengaluru',
 'Possession DateJun, 2018',
 'Average Price₹9.50 K/sq.ft',
 'Possession StatusReady to Move',
 'Possession DateJun, 2018',
 'Average Price₹9.50 K/sq.ft',
 'Possession StatusReady to Move',
 'Sizes2800.00 sq.ft. - 6877.00 sq.ft.',
 'LocalityWhitefield,Bangalore East ,Bangalore',
 'Project NameLake Waters',
 'Builtup area2869 sq.ft',
 'Average Price₹8.12k/sq.ft',
 'Project NameLake Waters',
 'Builtup area2869 sq.ft',
 'Average Price₹8.12k/sq.ft',
 'Main entrance facingWest Facing',
 'FurnishingUnfurnished',
 'Balcony2 Balcony',
 'Parking2',
 'BrokerageNo Charge',
 'LocalityNallurhalli, Whitefield,Bangalore',
 'Project NameNVT Stopping By The Woods',
 'Builtup area3444 sq.ft',
 'Average Price₹11.79k/sq.ft',
 'Project NameNVT Stopping By The Woods',
 'Builtup area3444 sq.ft',
 'Average Price₹11.79k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingUnfurnished',
 'Balcony3 Balcony',
 'Parking1',
 'BrokerageNo Charge',
 'LocalitySathya Sai Layout, Whitefield,Bangalore',
 'Project NameEncore In The Shire',
 'Builtup area2636 sq.ft',
 'Average Price₹8.04k/sq.ft',
 'Project NameEncore In The Shire',
 'Builtup area2636 sq.ft',
 'Average Price₹8.04k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingUnfurnished',
 'Balcony3 Balcony',
 'Parking2',
 'BrokerageNo Charge',
 'LocalityNallurhalli, Whitefield,Bangalore',
 'Project NamePrestige Laughing Waters',
 'Builtup area2400 sq.ft',
 'Average Price₹18.71k/sq.ft',
 'Project NamePrestige Laughing Waters',
 'Builtup area2400 sq.ft',
 'Average Price₹18.71k/sq.ft',
 'Main entrance facingNorth-west Facing',
 'FurnishingUnfurnished',
 'Balcony3 Balcony',
 'Parking2',
 'Brokerage₹4.5 Lacs',
 'LocalitySiddapura, Whitefield,Bangalore',
 'Project NameSBR Florenso',
 'Builtup area1840 sq.ft',
 'Average Price₹8.1k/sq.ft',
 'Project NameSBR Florenso',
 'Builtup area1840 sq.ft',
 'Average Price₹8.1k/sq.ft',
 'Main entrance facingNorth Facing',
 'FurnishingUnfurnished',
 'Balcony1 Balcony',
 'Parking1',
 'BrokerageNo Charge',
 'LocalityAmbedkar Nagar, Whitefield,Bangalore',
 'Project NamePrestige Ozone',
 'Builtup area2040 sq.ft',
 'Average Price₹21.57k/sq.ft',
 'Project NamePrestige Ozone',
 'Builtup area2040 sq.ft',
 'Average Price₹21.57k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingSemi Furnished',
 'Balcony2 Balcony',
 'Parking2',
 'Brokerage₹8.8 Lacs',
 'LocalityPrestige Ozone, Whitefield,Bangalore',
 'Project NameAdarsh Palm Meadows Annexe',
 'Builtup area2880 sq.ft',
 'Average Price₹21.53k/sq.ft',
 'Project NameAdarsh Palm Meadows Annexe',
 'Builtup area2880 sq.ft',
 'Average Price₹21.53k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingSemi Furnished',
 'Balcony2 Balcony',
 'Parking2',
 'Brokerage₹12.4 Lacs',
 'LocalityPhase 1, Whitefield,Bangalore',
 'Project NameChaithanya Oakville',
 'Builtup area6012 sq.ft',
 'Average Price₹10.86k/sq.ft',
 'Project NameChaithanya Oakville',
 'Builtup area6012 sq.ft',
 'Average Price₹10.86k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingUnfurnished',
 'Balcony2 Balcony',
 'Parking3',
 'BrokerageNo Charge',
 'LocalityNarayanappa Garden, Whitefield,Bangalore',
 'Project NamePrestige Ozone',
 'Builtup area4030 sq.ft',
 'Average Price₹17.15k/sq.ft',
 'Project NamePrestige Ozone',
 'Builtup area4030 sq.ft',
 'Average Price₹17.15k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingUnfurnished',
 'Balcony3 Balcony',
 'Parking3',
 'BrokerageNo Charge',
 'LocalityPrestige Ozone, Whitefield,Bangalore',
 'Project NamePrestige Ozone',
 'Builtup area2150 sq.ft',
 'Average Price₹20.56k/sq.ft',
 'Project NamePrestige Ozone',
 'Builtup area2150 sq.ft',
 'Average Price₹20.56k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingSemi Furnished',
 'Balcony2 Balcony',
 'Parking2',
 'Brokerage₹9.0 Lacs',
 'LocalityPrestige Ozone, Whitefield,Bangalore',
 'Project NamePrestige White Meadows',
 'Builtup area6120 sq.ft',
 'Average Price₹14.0k/sq.ft',
 'Project NamePrestige White Meadows',
 'Builtup area6120 sq.ft',
 'Average Price₹14.0k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingUnfurnished',
 'Balcony2 Balcony',
 'Parking3',
 'BrokerageNo Charge',
 'LocalitySathya Sai Layout, Whitefield,Bangalore',
 'Project NamePrestige Somerville',
 'Builtup area4600 sq.ft',
 'Average Price₹13.04k/sq.ft',
 'Project NamePrestige Somerville',
 'Builtup area4600 sq.ft',
 'Average Price₹13.04k/sq.ft',
 'FurnishingUnfurnished',
 'Balcony3 Balcony',
 'Parking2',
 'BrokerageNo Charge',
 'LocalityRamagondanahalli, Whitefield,Bangalore',
 'Project NameDSR Elixir',
 'Builtup area3285 sq.ft',
 'Average Price₹10.0k/sq.ft',
 'Project NameDSR Elixir',
 'Builtup area3285 sq.ft',
 'Average Price₹10.0k/sq.ft',
 'Main entrance facingWest Facing',
 'FurnishingUnfurnished',
 'Balcony3 Balcony',
 'Parking2',
 'BrokerageNo Charge',
 'LocalityPrithvi Layout, Whitefield,Bangalore',
 'Project NameAdarsh Palm Meadows',
 'Builtup area5750 sq.ft',
 'Average Price₹19.13k/sq.ft',
 'Project NameAdarsh Palm Meadows',
 'Builtup area5750 sq.ft',
 'Average Price₹19.13k/sq.ft',
 'Main entrance facingWest Facing',
 'FurnishingSemi Furnished',
 'Balcony2 Balcony',
 'Parking2',
 'Brokerage₹11.0 Lacs',
 'LocalityPhase 1, Whitefield,Bangalore',
 'Project NameKonig Orange County',
 'Builtup area1550 sq.ft',
 'Average Price₹17.74k/sq.ft',
 'Project NameKonig Orange County',
 'Builtup area1550 sq.ft',
 'Average Price₹17.74k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingUnfurnished',
 'Balcony3 Balcony',
 'Parking1',
 'BrokerageNo Charge',
 'LocalityNallurhalli, Whitefield,Bangalore',
 'Project NamePrestige White Meadows Villas',
 'Builtup area6219 sq.ft',
 'Average Price₹11.26k/sq.ft',
 'Project NamePrestige White Meadows Villas',
 'Builtup area6219 sq.ft',
 'Average Price₹11.26k/sq.ft',
 'Main entrance facingSouth Facing',
 'FurnishingUnfurnished',
 'Parking6',
 'Brokerage₹7.0 Lacs',
 'LocalitySathya Sai Layout, Whitefield,Bangalore',
 'Project NameTotal Windmills of Your Mind Villas',
 'Builtup area3756 sq.ft',
 'Average Price₹18.64k/sq.ft',
 'Project NameTotal Windmills of Your Mind Villas',
 'Builtup area3756 sq.ft',
 'Average Price₹18.64k/sq.ft',
 'FurnishingSemi Furnished',
 'Balcony2 Balcony',
 'Parking4',
 'Brokerage₹8.0 Lacs',
 'LocalityBasavanna Nagar, Whitefield,Bangalore',
 'Project NamePrestige White Meadows',
 'Builtup area10000 sq.ft',
 'Average Price₹16.0k/sq.ft',
 'Project NamePrestige White Meadows',
 'Builtup area10000 sq.ft',
 'Average Price₹16.0k/sq.ft',
 'Main entrance facingNorth-east Facing',
 'FurnishingSemi Furnished',
 'Balcony4 Balcony',
 'Parking6',
 'Brokerage₹16.0 Lacs',
 'LocalitySathya Sai Layout, Whitefield,Bangalore',
 'Project NameTotal Windmills of Your Mind Villas',
 'Builtup area3756 sq.ft',
 'Average Price₹21.3k/sq.ft',
 'Project NameTotal Windmills of Your Mind Villas',
 'Builtup area3756 sq.ft',
 'Average Price₹21.3k/sq.ft',
 'FurnishingSemi Furnished',
 'Balcony2 Balcony',
 'Parking4',
 'Brokerage₹8.0 Lacs',
 'LocalityBasavanna Nagar, Whitefield,Bangalore',
 'Project NameChaithanya Oak Villa',
 'Builtup area5205 sq.ft',
 'Average Price₹10.76k/sq.ft',
 'Project NameChaithanya Oak Villa',
 'Builtup area5205 sq.ft',
 'Average Price₹10.76k/sq.ft',
 'Main entrance facingSouth-east Facing',
 'FurnishingFully Furnished',
 'Balcony2 Balcony',
 'Parking3',
 'Brokerage₹5.6 Lacs',
 'LocalityChaithanya Oak Villa,Nallurhalli, Whitefield,Bangalore',
 'Project NamePrestige Bougainvilla',
 'Builtup area3859 sq.ft',
 'Average Price₹14.25k/sq.ft',
 'Project NamePrestige Bougainvilla',
 'Builtup area3859 sq.ft',
 'Average Price₹14.25k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingFully Furnished',
 'Balcony2 Balcony',
 'Parking2',
 'Brokerage₹5.5 Lacs',
 'LocalityPrestige Bougainvilla,Nallurhalli, Whitefield,Bangalore',
 'Project NamePrestige Boulevard',
 'Builtup area3859 sq.ft',
 'Average Price₹14.9k/sq.ft',
 'Project NamePrestige Boulevard',
 'Builtup area3859 sq.ft',
 'Average Price₹14.9k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingFully Furnished',
 'Parking4',
 'Brokerage₹5.8 Lacs',
 'LocalityDodsworth Layout, Whitefield,Bangalore',
 'Project NameTotal Windmills of Your Mind Villas',
 'Builtup area3756 sq.ft',
 'Average Price₹18.64k/sq.ft',
 'Project NameTotal Windmills of Your Mind Villas',
 'Builtup area3756 sq.ft',
 'Average Price₹18.64k/sq.ft',
 'Main entrance facingSouth-east Facing',
 'FurnishingSemi Furnished',
 'Balcony2 Balcony',
 'Parking4',
 'Brokerage₹8.0 Lacs',
 'LocalityBasavanna Nagar, Whitefield,Bangalore',
 'Project NameDSR Elixir',
 'Builtup area2705 sq.ft',
 'Average Price₹9.98k/sq.ft',
 'Project NameDSR Elixir',
 'Builtup area2705 sq.ft',
 'Average Price₹9.98k/sq.ft',
 'Main entrance facingEast Facing',
 'FurnishingUnfurnished',
 'Balcony3 Balcony',
 'Parking3',
 'BrokerageNo Charge',
 'LocalityPrithvi Layout, Whitefield,Bangalore'
    
]

project_names = []
builtup_areas = []
average_prices = []
main_entrances = []
furnishings = []
balconies = []
parkings = []
brokerages = []

current_project = {}
for item in data:
    if item.startswith("Project Name"):
        project_names.append(item.split("Project Name")[1].strip())
    elif item.startswith("Builtup area"):
        builtup_areas.append(item.split("Builtup area")[1].strip())
    elif item.startswith("Average Price"):
        average_prices.append(item.split("Average Price")[1].strip())
    elif item.startswith("Main entrance facing"):
        main_entrances.append(item.split("Main entrance facing")[1].strip())
    elif item.startswith("Furnishing"):
        furnishings.append(item.split("Furnishing")[1].strip())
    elif item.startswith("Balcony"):
        balconies.append(item.split("Balcony")[1].strip())
    elif item.startswith("Parking"):
        parkings.append(item.split("Parking")[1].strip())
    elif item.startswith("Brokerage"):
        brokerages.append(item.split("Brokerage")[1].strip())

print("Project Names:", project_names)
print("Builtup Areas:", builtup_areas)
print("Average Prices:", average_prices)
print("Main Entrances:", main_entrances)
print("Furnishings:", furnishings)
print("Balconies:", balconies)
print("Parkings:", parkings)
print("Brokerages:", brokerages)
# Out:
# Project Names: ['Lake Waters', 'Lake Waters', 'NVT Stopping By The Woods', 'NVT Stopping By The Woods', 'Encore In The Shire', 'Encore In The Shire', 'Prestige Laughing Waters', 'Prestige Laughing Waters', 'SBR Florenso', 'SBR Florenso', 'Prestige Ozone', 'Prestige Ozone', 'Adarsh Palm Meadows Annexe', 'Adarsh Palm Meadows Annexe', 'Chaithanya Oakville', 'Chaithanya Oakville', 'Prestige Ozone', 'Prestige Ozone', 'Prestige Ozone', 'Prestige Ozone', 'Prestige White Meadows', 'Prestige White Meadows', 'Prestige Somerville', 'Prestige Somerville', 'DSR Elixir', 'DSR Elixir', 'Adarsh Palm Meadows', 'Adarsh Palm Meadows', 'Konig Orange County', 'Konig Orange County', 'Prestige White Meadows Villas', 'Prestige White Meadows Villas', 'Total Windmills of Your Mind Villas', 'Total Windmills of Your Mind Villas', 'Prestige White Meadows', 'Prestige White Meadows', 'Total Windmills of Your Mind Villas', 'Total Windmills of Your Mind Villas', 'Chaithanya Oak Villa', 'Chaithanya Oak Villa', 'Prest
# ...

# %%
print(len(price),len(address_list),len(bhk_list),len(project_names),len(builtup_areas),len(average_prices),len(main_entrances)
,len(furnishings),
len(balconies),
len(parkings),
len(brokerages))
# Out:
# 30 24 24 48 48 60 21 24 22 24 24

# %%
import numpy as np

length = max(len(project_names), len(builtup_areas), len(average_prices), len(main_entrances),
             len(furnishings), len(balconies), len(parkings), len(brokerages), len(price), len(address_list), len(bhk_list))

project_names += [np.nan] * (length - len(project_names))
builtup_areas += [np.nan] * (length - len(builtup_areas))
average_prices += [np.nan] * (length - len(average_prices))
main_entrances += [np.nan] * (length - len(main_entrances))
furnishings += [np.nan] * (length - len(furnishings))
balconies += [np.nan] * (length - len(balconies))
parkings += [np.nan] * (length - len(parkings))
brokerages += [np.nan] * (length - len(brokerages))
price += [np.nan] * (length - len(price))
address_list += [np.nan] * (length - len(address_list))
bhk_list += [np.nan] * (length - len(bhk_list))

print("Length of Price:", len(price))
print("Length of Address List:", len(address_list))
print("Length of BHK List:", len(bhk_list))
print("Length of Project Names:", len(project_names))
print("Length of Builtup Areas:", len(builtup_areas))
print("Length of Average Prices:", len(average_prices))
print("Length of Main Entrances:", len(main_entrances))
print("Length of Furnishings:", len(furnishings))
print("Length of Balconies:", len(balconies))
print("Length of Parkings:", len(parkings))
print("Length of Brokerages:", len(brokerages))
# Out:
# Length of Price: 60
# Length of Address List: 60
# Length of BHK List: 60
# Length of Project Names: 60
# Length of Builtup Areas: 60
# Length of Average Prices: 60
# Length of Main Entrances: 60
# Length of Furnishings: 60
# Length of Balconies: 60
# Length of Parkings: 60
# Length of Brokerages: 60

# %%
data_dict = {
    'Project Names': project_names,
    'Builtup Areas': builtup_areas,
    'Average Prices': average_prices,
    'Main Entrances': main_entrances,
    'Furnishings': furnishings,
    'Balconies': balconies,
    'Parkings': parkings,
    'Brokerages': brokerages,
    'Price': price,
    'Address List': address_list,
    'BHK List': bhk_list
}
df = pd.DataFrame(data_dict)
print(df)
# Out:
#                           Project Names Builtup Areas  \
# 0                           Lake Waters    2869 sq.ft
# 1                           Lake Waters    2869 sq.ft
# 2             NVT Stopping By The Woods    3444 sq.ft
# 3             NVT Stopping By The Woods    3444 sq.ft
# 4                   Encore In The Shire    2636 sq.ft
# 5                   Encore In The Shire    2636 sq.ft
# 6              Prestige Laughing Waters    2400 sq.ft
# 7              Prestige Laughing Waters    2400 sq.ft
# 8                          SBR Florenso    1840 sq.ft
# 9                          SBR Florenso    1840 sq.ft
# 10                       Prestige Ozone    2040 sq.ft
# 11                       Prestige Ozone    2040 sq.ft
# 12           Adarsh Palm Meadows Annexe    2880 sq.ft
# 13           Adarsh Palm Meadows Annexe    2880 sq.ft
# 14                  Chaithanya Oakville    6012 sq.ft
# 15                  Chaithanya Oakville    6012 sq.ft
# ...

# %%
df.to_csv('prices_per_sqft.csv', index=False)
